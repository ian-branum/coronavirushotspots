# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import pandas as pd
import src.data_import as di
#from src.poly_reg import model_county
#from src.poly_reg import model_state
#from src.data_import import nyt

plt.style.use('ggplot')
font = {'weight' : 'bold',
        'size'   : 18}

plt.rc('font', **font)

# %%
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', None)

# %%
df = nyt()
print('done')
# Out:
# done

# %%
hhi_df = di.extract_hhi()

# %%
hhi_df[hhi_df['state'] == 'California']
# Out:
#           state                  county  Estimate!!Households!!Total  \
# 4    California        Mendocino County                        33794
# 5    California           Orange County                      1040394
# 6    California       Sacramento County                       543560
# 61   California             Yuba County                        26191
# 83   California         Humboldt County                        55773
# 84   California           Madera County                        44484
# 153  California          Ventura County                       271980
# 207  California    Santa Barbara County                       146224
# 234  California            Kings County                        43727
# 235  California           Shasta County                        68198
# 251  California     Contra Costa County                       396133
# 300  California  San Luis Obispo County                       106198
# 340  California       Santa Cruz County                        94994
# ...

# %%
df2 = di.extract_public_transport()

# %%
len(df2)
# Out:
# 838

# %%
df2.head()
# Out:
#         state      county  \
# 0     Alabama      Shelby
# 1     Alabama   Talladega
# 2     Alabama  Tuscaloosa
# 3     Arizona       Pinal
# 4  California   Mendocino
#
#   Estimate!!Total!!Workers 16 years and over!!MEANS OF TRANSPORTATION TO WORK!!Public transportation (excluding taxicab)
# 0                                                0.0
# 1                                                  N
# 2                                                0.2
# 3                                                0.2
# 4                                                0.0

# %%
df3 = di.extract_edu()

# %%
df3.head()
len(df3)
# Out:
# 838

# %%
def hhi(fn="./data/raw/Census/2018 HHI.csv"):
    df = pd.read_csv(fn)
#    df = df.apply(fixdata, axis=1)
    return df
df4 = hhi()
df4[df4['Postal Code'] == 'CA']

# %%
# Out:
#      State FIPS Code  County FIPS Code Postal Code                    Name  \
# 191                6                 0          CA              California
# 192                6                 1          CA          Alameda County
# 193                6                 3          CA           Alpine County
# 194                6                 5          CA           Amador County
# 195                6                 7          CA            Butte County
# 196                6                 9          CA        Calaveras County
# 197                6                11          CA           Colusa County
# 198                6                13          CA     Contra Costa County
# 199                6                15          CA        Del Norte County
# 200                6                17          CA        El Dorado County
# 201                6                19          CA           Fresno County
# ...

# %%
len(df4[df4['Postal Code'] == 'CA'])
# Out:
# 59

# %%
def housing(fn="./data/raw/Census/housing.csv"):
    df = pd.read_csv(fn)
#    df = df.apply(fixdata, axis=1)
    return df
df5 = di.extract_housing()

# %%
df5.head()
# Out:
#         state    county  \
# 0     Alabama    Morgan
# 1  California     Kings
# 2  California  Monterey
# 3  California    Nevada
# 4  California    Shasta
#
#    Estimate!!VALUE!!Owner-occupied units!!Median (dollars)  \
# 0                                             139700
# 1                                             231100
# 2                                             563000
# 3                                             456000
# 4                                             265000
#
#    Estimate!!GROSS RENT!!Occupied units paying rent!!Median (dollars)  \
# 0                                                710
# 1                                               1083
# 2                                               1511
# 3                                               1256
# 4                                               1084
#
#    Percent Estimate!!HOUSING OCCUPANCY!!Total housing units  \
# 0                                              52284
# ...

# %%
len(df5[df5['state'] == 'California'])
# Out:
# 40
