# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import pandas as pd
from src.poly_reg import model_county
from src.poly_reg import model_state
from src.data_import import nyt

plt.style.use('ggplot')
font = {'weight' : 'bold',
        'size'   : 18}

plt.rc('font', **font)

# %%
df = nyt()
print('done')
# Out:
# done

# %%
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', None)

def median_hhi(fn="./data/raw/Census/HH_income.csv"):
    df = pd.read_csv(fn)
#    df = df.apply(fixdata, axis=1)
    return df
df = median_hhi()

# %%
len(df)
# Out:
# 838

# %%
df.head()
# Out:
#                id          Geographic Area Name  Estimate!!Households!!Total  \
# 0  0500000US01117        Shelby County, Alabama                        80944
# 1  0500000US01121     Talladega County, Alabama                        31219
# 2  0500000US01125    Tuscaloosa County, Alabama                        74053
# 3  0500000US04021         Pinal County, Arizona                       147936
# 4  0500000US06045  Mendocino County, California                        33794
#
#    Margin of Error!!Households MOE!!Total  Estimate!!Families!!Total  \
# 0                                    1588                      55341
# 1                                    1460                      21701
# 2                                    2334                      48006
# 3                                    3458                     109641
# 4                                    1416                      21433
#
#    Margin of Error!!Families MOE!!Total  \
# 0                                  2373
# ...

# %%
df[['Geographic Area Name', 'Estimate!!Households!!Total','Estimate!!Households!!Median income (dollars)']].head()
# Out:
#            Geographic Area Name  Estimate!!Households!!Total  \
# 0        Shelby County, Alabama                        80944
# 1     Talladega County, Alabama                        31219
# 2    Tuscaloosa County, Alabama                        74053
# 3         Pinal County, Arizona                       147936
# 4  Mendocino County, California                        33794
#
#    Estimate!!Households!!Median income (dollars)
# 0                                          71230
# 1                                          40315
# 2                                          54459
# 3                                          59058
# 4                                          51830

# %%
def lots_o_data(fn="./data/raw/Census/lots_of_census_data.csv"):
    df = pd.read_csv(fn)
#    df = df.apply(fixdata, axis=1)
    return df
df2 = lots_o_data()

# %%
len(df2)
# Out:
# 141

# %%
df2.head()
# Out:
#                id  Race/Ethnic Group Population Groups  \
# 0  0500000US06071                  1  Total population
# 1  0500000US06073                  1  Total population
# 2  0500000US06077                  1  Total population
# 3  0500000US09001                  1  Total population
# 4  0500000US09003                  1  Total population
#
#                 Geographic Area Name  \
# 0  San Bernardino County, California
# 1       San Diego County, California
# 2     San Joaquin County, California
# 3      Fairfield County, Connecticut
# 4       Hartford County, Connecticut
#
#    Estimate!!TOTAL NUMBER OF RACES REPORTED!!Total population  \
# 0                                            2171603
# 1                                            3343364
# 2                                             752660
# 3                                             943823
# 4                                             892697
#
# ...

# %%
df2[['Geographic Area Name',
     'Estimate!!HOUSEHOLDS BY TYPE!!Households',
     'Estimate!!SEX AND AGE!!Total population!!Median age (years)',
     'Estimate!!SEX AND AGE!!Total population!!18 years and over',
     'Estimate!!SEX AND AGE!!Total population!!62 years and over',
     'Estimate!!COMMUTING TO WORK!!Workers 16 years and over!!Public transportation (excluding taxicab)', 
     'Estimate!!INCOME IN THE PAST 12 MONTHS (IN 2018 INFLATION-ADJUSTED DOLLARS)!!Households!!Median household income (dollars)',
     'Estimate!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Less than high school diploma',
     'Estimate!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!High school graduate (includes equivalency)',
     'Estimate!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Some college or associate\'s degree',
     'Estimate!!EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Bachelor\'s degree or higher',
     'Estimate!!UNITS IN STRUCTURE!!Occupied housing units!!1-unit detached or attached'
    ]].head()
# Out:
#                 Geographic Area Name  \
# 0  San Bernardino County, California
# 1       San Diego County, California
# 2     San Joaquin County, California
# 3      Fairfield County, Connecticut
# 4       Hartford County, Connecticut
#
#    Estimate!!HOUSEHOLDS BY TYPE!!Households  \
# 0                                    638647
# 1                                   1130911
# 2                                    231917
# 3                                    345634
# 4                                    348049
#
#    Estimate!!SEX AND AGE!!Total population!!Median age (years)  \
# 0                                               33.6
# 1                                               36.1
# 2                                               34.5
# 3                                               40.8
# 4                                               40.3
#
#    Estimate!!SEX AND AGE!!Total population!!18 years and over  \
# 0                                               73.6
# ...

# %%
len(df2)
# Out:
# 141

# %%
def edu(fn="./data/raw/Census/edu.csv"):
    df = pd.read_csv(fn)
#    df = df.apply(fixdata, axis=1)
    return df
df3 = edu()

# %%
df3.head()
# Out:
#                id          Geographic Area Name  \
# 0  0500000US01117        Shelby County, Alabama
# 1  0500000US01121     Talladega County, Alabama
# 2  0500000US01125    Tuscaloosa County, Alabama
# 3  0500000US04021         Pinal County, Arizona
# 4  0500000US06045  Mendocino County, California
#
#    Estimate!!Total!!Population 18 to 24 years  \
# 0                                       17648
# 1                                        6743
# 2                                       34257
# 3                                       36982
# 4                                        7686
#
#   Margin of Error!!Total MOE!!Population 18 to 24 years  \
# 0                                                776
# 1                                                138
# 2                                                807
# 3                                               1348
# 4                                                804
#
#   Estimate!!Percent!!Population 18 to 24 years  \
# ...

# %%
df3['county'] = df3['Geographic Area Name'].str.split(",",expand=True,)[0]
df3['state'] = df3['Geographic Area Name'].str.split(",",expand=True,)[1]

# %%
df4 = df3[df3['state'] == ' California']
len(df4['Geographic Area Name'].unique())
# Out:
# 40

# %%
def hhi(fn="./data/raw/Census/cc-est2018-alldata.csv"):
    df = pd.read_csv(fn)
#    df = df.apply(fixdata, axis=1)
    return df
df4 = hhi()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xf1 in position 2: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-31-99d784ea3125> in <module>
#       3 #    df = df.apply(fixdata, axis=1)
#       4     return df
# ----> 5 df4 = hhi()
#
# <ipython-input-31-99d784ea3125> in hhi(fn)
#       1 def hhi(fn="./data/raw/Census/cc-est2018-alldata.csv"):
# ...

# %%
df4.head()
# Out:
#    State FIPS Code  County FIPS Code Postal Code            Name  \
# 0                0                 0          US   United States
# 1                1                 0          AL         Alabama
# 2                1                 1          AL  Autauga County
# 3                1                 3          AL  Baldwin County
# 4                1                 5          AL  Barbour County
#
#   Median Household Income
# 0                  61,937
# 1                  49,881
# 2                  59,338
# 3                  57,588
# 4                  34,382

# %%
#len(df4['Name'].unique())
len(df4[df4['Postal Code'] == 'CA'])
# Out:
# 59
